# %%
#BFS

# %%
#Adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

# %%
import networkx as nx
import matplotlib.pyplot as plt
# Create a directed graph
G = nx.DiGraph()
# Add edges from adjacency list
for node, neighbors in graph.items():
    for neighbor in neighbors:
        G.add_edge(node, neighbor)
# Draw the graph
plt.figure(figsize=(6, 6))
pos = nx.spring_layout(G)  # layout for positioning nodes
nx.draw(
    G, pos,
    with_labels=True,
    node_size=2000,
    node_color="lightblue",
    font_size=12,
    font_weight="bold",
    arrows=True,
    arrowsize=20
)
plt.title("Graph Visualization using NetworkX")
plt.show()

# %% [markdown]
# ![Sample Image](https://miro.medium.com/v2/resize:fit:640/format:webp/1*GT9oSo0agIeIj6nTg3jFEA.gif)

# %%
# BFS

# %%
from collections import deque

def bfs(graph, start, goal=None):
    visited = set()
    queue = deque([start]) #o(1) constant time in dequeue and (on) linear time in list

    print(f"Start BFS from: {start}")
    print(f"Initial Queue: {list(queue)}\n")

    while queue:
        node = queue.popleft()
        if node not in visited:
            print(f"Visit: {node}")
            visited.add(node)
            print(f"Visited Set: {visited}")

            # Check if goal is reached
            if node == goal:
                print(f"Goal {goal} found!")
                return

            # Add all unvisited neighbors
            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append(neighbor)

            print(f"Queue after exploring {node}: {list(queue)}\n")

    if goal:
        print(f"Goal {goal} not found in graph.")

# %%
print("BFS Traversal with Steps:\n")
bfs(graph, 'A', goal='F')  # searching for F
# Out:
# BFS Traversal with Steps:
#
# Start BFS from: A
# Initial Queue: ['A']
#
# Visit: A
# Visited Set: {'A'}
# Queue after exploring A: ['B', 'C']
#
# Visit: B
# Visited Set: {'B', 'A'}
# Queue after exploring B: ['C', 'D', 'E']
#
# Visit: C
# Visited Set: {'B', 'C', 'A'}
# Queue after exploring C: ['D', 'E', 'F']
#
# Visit: D
# Visited Set: {'D', 'B', 'C', 'A'}
# Queue after exploring D: ['E', 'F']
#
# Visit: E
# Visited Set: {'E', 'D', 'C', 'A', 'B'}
# Queue after exploring E: ['F', 'F']
#
# Visit: F
# Visited Set: {'E', 'D', 'C', 'A', 'F', 'B'}
# Goal F found!

# %%
#DFS iterative

# %%
def dfs(graph, start, goal=None):
    visited = set()
    stack = [start]

    print(f"Start DFS from: {start}")
    print(f"Initial Stack: {stack}\n")

    while stack:
        node = stack.pop()
        if node not in visited:
            print(f"Visit: {node}")
            visited.add(node)
            print(f"Visited Set: {visited}")

            # Check if goal is found
            if node == goal:
                print(f"Goal {goal} found!")
                return True

            # Push neighbors in reverse order (to keep left-to-right order)
            for neighbor in reversed(graph[node]):
                if neighbor not in visited:
                    stack.append(neighbor)

            print(f"Stack after exploring {node}: {stack}\n")

    if goal:
        print(f"Goal {goal} not found in graph.")
    return False

# %%
print("DFS Traversal with Goal:\n")
dfs(graph, 'A', goal='F')
# Out:
# DFS Traversal with Goal:
#
# Start DFS from: A
# Initial Stack: ['A']
#
# Visit: A
# Visited Set: {'A'}
# Stack after exploring A: ['C', 'B']
#
# Visit: B
# Visited Set: {'A', 'B'}
# Stack after exploring B: ['C', 'E', 'D']
#
# Visit: D
# Visited Set: {'A', 'B', 'D'}
# Stack after exploring D: ['C', 'E']
#
# Visit: E
# Visited Set: {'A', 'E', 'B', 'D'}
# Stack after exploring E: ['C', 'F']
#
# Visit: F
# Visited Set: {'A', 'E', 'F', 'B', 'D'}
# Goal F found!
# True
